# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
data = {
    "Review": [
        "This phone is amazing and fast",
        "Battery life is very bad",
        "Camera quality is good",
        "Not worth the price",
        "Excellent performance and design",
        "Average experience",
        "I love this mobile",
        "Very disappointing product"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                              Review
# 0    This phone is amazing and fast
# 1          Battery life is very bad
# 2            Camera quality is good
# 3               Not worth the price
# 4  Excellent performance and design
# 5                Average experience
# 6                I love this mobile
# 7        Very disappointing product

# %%
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Review"].apply(get_sentiment)

df
# Out:
#                              Review Sentiment
# 0    This phone is amazing and fast  Positive
# 1          Battery life is very bad  Negative
# 2            Camera quality is good  Positive
# 3               Not worth the price  Negative
# 4  Excellent performance and design  Positive
# 5                Average experience  Negative
# 6                I love this mobile  Positive
# 7        Very disappointing product  Negative

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Positive    4
# Negative    4
# Name: count, dtype: int64

# %%
df["Sentiment"].value_counts().plot(kind="bar")

plt.title("Sentiment Analysis Results")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
